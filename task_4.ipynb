# %% [markdown]
# <a href="https://colab.research.google.com/github/sarathkumar355/PRODIGY_DS_04/blob/main/task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
file_path = "twitter_training.csv"  # Update with your actual file path
df = pd.read_csv(file_path, encoding="utf-8", header=None)
df.columns = ['ID', 'Topic', 'Sentiment', 'Text']

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Sentiment'], palette='coolwarm')
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-3-afbdd5e706bc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Sentiment'], palette='coolwarm')

# %%
positive_text = " ".join(df[df['Sentiment'] == 'Positive']['Text'].fillna(""))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Positive Sentiment")
plt.show()
